# %% [markdown]
# # CS4350/7350 - Big Data Analytics
# ## Phase 2 Starter Notebook: Spark ML Pipeline (Jigsaw Toxic Comment Dataset)
#
# ### Purpose
# This notebook uses the **Jigsaw Toxic Comment Classification Challenge** training data with **Apache Spark (PySpark) and Spark ML Pipelines**.
#
# ### Important
# - You must use:
#   - **Spark DataFrames**
#   - **Spark MLlib**
#   - **Spark ML Pipelines**
# - Using only `pandas`, `scikit-learn`, or non-Spark ML code does **not** satisfy the project requirements.
#
# ### What you still must complete
# You are expected to:
# 1. Download the Kaggle Jigsaw toxic comment data
# 2. Run the notebook using Spark
# 3. Review and improve comments where needed
# 4. Verify all required metrics
# 5. Add interpretation and discussion
# 6. Write the 3-4 page report

# %% [markdown]
# ## Environment Setup
#
# Recommended options:
# 1. **Databricks Community Edition**
# 2. **Local PySpark installation**
#
# This notebook expects the Kaggle competition training file from:
# https://www.kaggle.com/competitions/jigsaw-toxic-comment-classification-challenge/data
#
# Download `train.csv.zip` from Kaggle and place it in this notebook directory, or extract it and place `train.csv` here. The code below will use `train.csv` directly or extract it from `train.csv.zip` if needed.

# %%
# If PySpark is missing, run this once in a notebook cell:
# %pip install pyspark

# %%
# Local Kaggle file names.
DATA_PATH = "data/train.csv"

# Databricks example after uploading the CSV:
# DATA_PATH = "/FileStore/tables/train.csv"

# %%
# sets JAVA_HOME for Spark to work properly on macOS with Java 21
import os
os.environ["JAVA_HOME"] = "/Library/Java/JavaVirtualMachines/temurin-21.jdk/Contents/Home"

from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.ml import Pipeline
from pyspark.ml.feature import Tokenizer, StopWordsRemover, HashingTF, IDF
from pyspark.ml.classification import (
    LogisticRegression,
    DecisionTreeClassifier,
    RandomForestClassifier,
    GBTClassifier,
    LinearSVC,
    NaiveBayes
)
from pyspark.ml.evaluation import MulticlassClassificationEvaluator
# Start Spark
spark = SparkSession.builder.appName("CS4350_7350_Phase2_Toxic_Comments").getOrCreate()
spark
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 26/04/30 13:23:07 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# 26/04/30 13:23:08 WARN Utils: Service 'SparkUI' could not bind on port 4040. Attempting port 4041.
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://atm0562066dyn.dhcp.missouri.edu:4041">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.1.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>CS4350_7350_Phase2_Toxic_Comments</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## 1. Load the Dataset into a Spark DataFrame
#
# The project requires the use of a **Spark DataFrame**, not a pandas DataFrame.
#
# The Kaggle training file contains the text column `comment_text` plus six binary toxicity labels:
# `toxic`, `severe_toxic`, `obscene`, `threat`, `insult`, and `identity_hate`.
#
# For this Spark ML starter workflow, we create one binary target named `label`: 1 if any toxicity column is positive, otherwise 0.

# %%
# Extract train.csv locally
if not os.path.exists(DATA_PATH):
    raise FileNotFoundError(
        f"Could not find {DATA_PATH}. Download train.csv.zip from Kaggle and place it in this folder."
    )

# Load the Jigsaw toxic comment training data.
raw_df = (
    spark.read
    .option("header", True)
    .option("inferSchema", True)
    .option("multiLine", True)
    .option("escape", '"')
    .csv(DATA_PATH)
)

toxic_cols = ["toxic", "severe_toxic", "obscene", "threat", "insult", "identity_hate"]

# Keep the text and create a single binary target for Spark binary classifiers.
df = (
    raw_df
    .select("id", "comment_text", *toxic_cols)
    .dropna(subset=["comment_text"])
    .withColumn(
        "label",
        (
            F.col("toxic").cast("int")
            + F.col("severe_toxic").cast("int")
            + F.col("obscene").cast("int")
            + F.col("threat").cast("int")
            + F.col("insult").cast("int")
            + F.col("identity_hate").cast("int")
            > 0
        ).cast("double")
    )
)
#df = df.sample(fraction=0.2, seed=42) # Sample 20% of the data for faster experimentation. REMOVE BEOFRE SUBMISSION!
print("Row count:", df.count())
print("Column count:", len(df.columns))
df.printSchema()
df.select("id", "comment_text", "label", *toxic_cols).show(5, truncate=80)
# Out:
# Row count: 159571
# Column count: 9
# root
#  |-- id: string (nullable = true)
#  |-- comment_text: string (nullable = true)
#  |-- toxic: integer (nullable = true)
#  |-- severe_toxic: integer (nullable = true)
#  |-- obscene: integer (nullable = true)
#  |-- threat: integer (nullable = true)
#  |-- insult: integer (nullable = true)
#  |-- identity_hate: integer (nullable = true)
#  |-- label: double (nullable = true)
#
# +----------------+--------------------------------------------------------------------------------+-----+-----+------------+-------+------+------+-------------+
# |              id|                                                                    comment_text|label|toxic|severe_toxic|obscene|threat|insult|identity_hate|
# +----------------+--------------------------------------------------------------------------------+-----+-----+------------+-------+------+------+-------------+
# |0000997932d777bf|Explanation\nWhy the edits made under my username Hardcore Metallica Fan were...|  0.0|    0|           0|      0|     0|     0|            0|
# |000103f0d9cfb60f|D'aww! He matches this background colour I'm seemingly stuck with. Thanks.  (...|  0.0|    0|           0|      0|     0|     0|            0|
# |000113f07ec002fd|Hey man, I'm really not trying to edit war. It's just that this guy is consta...|  0.0|    0|           0|      0|     0|     0|            0|
# |0001b41b1c6bb37e|"\nMore\nI can't make any real suggestions on improvement - I wondered if the...|  0.0|    0|           0|      0|     0|     0|            0|
# |0001d958c54c6e35|             You, sir, are my hero. Any chance you remember what page that's on?|  0.0|    0|           0|      0|     0|     0|            0|
# +----------------+--------------------------------------------------------------------------------+-----+-----+------------+-------+------+------+-------------+
# only showing top 5 rows

# %% [markdown]
# ## 2. Exploratory Data Analysis (EDA)
#
# Minimum expectations:
# - Show the schema
# - Show summary statistics
# - Show class distribution
# - Check for missing values
# - Review the label balance for the toxicity categories

# %%
# Summary statistics for binary label columns.
df.select("label", *toxic_cols).describe().show()

# Binary class distribution for the modeling label.
df.groupBy("label").count().orderBy("label").show()

# Individual toxicity label counts.
df.select([F.sum(F.col(c).cast("int")).alias(c) for c in toxic_cols]).show()

# Check for nulls.
null_counts = df.select([
    F.sum(F.col(c).isNull().cast("int")).alias(c) for c in df.columns
])
null_counts.show()
# Out:
# 26/04/30 13:23:13 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# +-------+-------------------+-------------------+--------------------+-----------------+--------------------+-------------------+-------------------+
# |summary|              label|              toxic|        severe_toxic|          obscene|              threat|             insult|      identity_hate|
# +-------+-------------------+-------------------+--------------------+-----------------+--------------------+-------------------+-------------------+
# |  count|             159571|             159571|              159571|           159571|              159571|             159571|             159571|
# |   mean|0.10167887648758234|0.09584448302009764|0.009995550569965721|0.052948217407925|0.002995531769557125|0.04936360616904074|0.00880485802558109|
# | stddev| 0.3022264961563371| 0.2943787715999705| 0.09947714085748408|0.223930832915411| 0.05464958623142267| 0.2166267172768179|0.09342048594149767|
# |    min|                0.0|                  0|                   0|                0|                   0|                  0|                  0|
# |    max|                1.0|                  1|                   1|                1|                   1|                  1|                  1|
# +-------+-------------------+-------------------+--------------------+-----------------+--------------------+-------------------+-------------------+
#
# +-----+------+
# |label| count|
# +-----+------+
# |  0.0|143346|
# |  1.0| 16225|
# +-----+------+
#
# +-----+------------+-------+------+------+-------------+
# |toxic|severe_toxic|obscene|threat|insult|identity_hate|
# +-----+------------+-------+------+------+-------------+
# |15294|        1595|   8449|   478|  7877|         1405|
# +-----+------------+-------+------+------+-------------+
#
# +---+------------+-----+------------+-------+------+------+-------------+-----+
# | id|comment_text|toxic|severe_toxic|obscene|threat|insult|identity_hate|label|
# +---+------------+-----+------------+-------+------+------+-------------+-----+
# |  0|           0|    0|           0|      0|     0|     0|            0|    0|
# +---+------------+-----+------------+-------+------+------+-------------+-----+

# %% [markdown]
# ## 3. Feature Engineering and Label Preparation
#
# We will:
# 1. Tokenize each comment
# 2. Remove common stop words
# 3. Convert tokens into hashed term-frequency vectors
# 4. Apply IDF weighting
# 5. Use the resulting vector as Spark ML features
#
# The target column is already numeric and named `label`.

# %%
# Text feature pipeline.
tokenizer = Tokenizer(inputCol="comment_text", outputCol="tokens")
stopwords = StopWordsRemover(inputCol="tokens", outputCol="filtered_tokens")
hashing_tf = HashingTF(inputCol="filtered_tokens", outputCol="tf_features", numFeatures=4096)
idf = IDF(inputCol="tf_features", outputCol="features")

base_pipeline = Pipeline(stages=[tokenizer, stopwords, hashing_tf, idf])
prepared_df = base_pipeline.fit(df).transform(df)

prepared_df.select("comment_text", "label", "features").show(5, truncate=80)
# Out:
# [Stage 18:>                                                         (0 + 1) / 1]
# +--------------------------------------------------------------------------------+-----+--------------------------------------------------------------------------------+
# |                                                                    comment_text|label|                                                                        features|
# +--------------------------------------------------------------------------------+-----+--------------------------------------------------------------------------------+
# |Explanation\nWhy the edits made under my username Hardcore Metallica Fan were...|  0.0|(4096,[147,199,280,424,495,763,1463,1476,1520,1568,1924,2022,2144,2218,2254,2...|
# |D'aww! He matches this background colour I'm seemingly stuck with. Thanks.  (...|  0.0|(4096,[23,618,918,995,1145,1418,1864,2011,2195,2536,3178,3420,3596,3666,4019]...|
# |Hey man, I'm really not trying to edit war. It's just that this guy is consta...|  0.0|(4096,[16,316,355,840,1099,1253,1358,1710,1774,2155,2218,2493,2734,2899,2954,...|
# |"\nMore\nI can't make any real suggestions on improvement - I wondered if the...|  0.0|(4096,[6,70,132,139,419,556,564,775,818,956,1080,1241,1268,1300,1307,1372,140...|
# |             You, sir, are my hero. Any chance you remember what page that's on?|  0.0|(4096,[373,389,1991,2762,2808,3183,3931],[4.956491555271761,4.37884817542647,...|
# +--------------------------------------------------------------------------------+-----+--------------------------------------------------------------------------------+
# only showing top 5 rows

# %% [markdown]
# ## 4. Train/Test Split
#
# Use a fixed seed for reproducibility.

# %%
# Split into training and testing sets
train_df, test_df = prepared_df.randomSplit([0.8, 0.2], seed=42)

print("Training rows:", train_df.count())
print("Testing rows:", test_df.count())
# Out:
# Training rows: 127502
# [Stage 23:>                                                         (0 + 1) / 1]
# Testing rows: 32069

# %% [markdown]
# ## 5. Approved Spark Models
#
# This binary toxic-comment target supports the following Spark-compatible classifiers:
#
# - Logistic Regression
# - Decision Tree Classifier
# - Random Forest Classifier
# - Gradient-Boosted Tree Classifier
# - Linear Support Vector Classifier
# - Naive Bayes
#
# All models use the same `features` vector created from the comment text.

# %%
# Binary classification models for the toxic comment dataset.
models = {
    "Logistic Regression": LogisticRegression(labelCol="label", featuresCol="features", maxIter=50),
    "Naive Bayes": NaiveBayes(labelCol="label", featuresCol="features", modelType="multinomial"),
    "Linear SVM": LinearSVC(labelCol="label", featuresCol="features", maxIter=100, regParam=0.01),
    "GBT Classifier": GBTClassifier(labelCol="label", featuresCol="features", maxIter=50, seed=42),
}

print("Training Logistic Regression and Naive Bayes binary Spark classifiers on the Jigsaw toxic comment target.")
# Out:
# Training Logistic Regression and Naive Bayes binary Spark classifiers on the Jigsaw toxic comment target.

# %%
# LinearSVC, GBTClassifier, and the other models above all support this binary label directly.

# %% [markdown]
# ## 6. Train and Evaluate Models
#
# Required metrics:
# - Accuracy
# - Precision
# - Recall
# - F1-score
#
# The comparison table below helps satisfy the model comparison requirement.

# %%
# Define evaluation metrics.
evaluators = {
    "accuracy": MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction", metricName="accuracy"),
    "f1": MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction", metricName="f1"),
    "weightedPrecision": MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction", metricName="weightedPrecision"),
    "weightedRecall": MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction", metricName="weightedRecall"),
}

# Train, predict, and evaluate each model.
results = []
predictions_dict = {}

for model_name, estimator in models.items():
    model = estimator.fit(train_df)
    preds = model.transform(test_df)
    predictions_dict[model_name] = preds

    row = {
        "model": model_name,
        "accuracy": evaluators["accuracy"].evaluate(preds),
        "f1": evaluators["f1"].evaluate(preds),
        "precision": evaluators["weightedPrecision"].evaluate(preds),
        "recall": evaluators["weightedRecall"].evaluate(preds),
    }
    results.append(row)

# Display results sorted by accuracy.
results_df = spark.createDataFrame(results).orderBy(F.desc("accuracy"))
results_df.show(truncate=False)
# Out:
# 26/04/30 13:23:45 WARN InstanceBuilder: Failed to load implementation from:dev.ludovic.netlib.blas.JNIBLAS
# 26/04/30 13:26:14 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 282.0 MiB so far)
# 26/04/30 13:26:14 WARN BlockManager: Persisting block rdd_536_0 to disk instead.
# 26/04/30 13:26:20 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:26:20 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 9.9 MiB so far)
# 26/04/30 13:26:24 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:26:26 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:26:28 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:26:31 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:26:33 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:26:33 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 9.9 MiB so far)
# 26/04/30 13:26:33 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 1043.8 KiB so far)
# 26/04/30 13:26:33 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_556_0 in memory.
# 26/04/30 13:26:33 WARN MemoryStore: Not enough space to cache rdd_556_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:26:33 WARN BlockManager: Persisting block rdd_556_0 to disk instead.
# 26/04/30 13:26:34 WARN MemoryStore: Not enough space to cache rdd_556_0 in memory! (computed 1035.5 KiB so far)
# 26/04/30 13:26:34 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_559_0 in memory.
# 26/04/30 13:26:34 WARN MemoryStore: Not enough space to cache rdd_559_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:26:34 WARN BlockManager: Persisting block rdd_559_0 to disk instead.
# 26/04/30 13:26:38 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:26:40 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:26:42 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:26:45 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:26:47 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:26:47 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 9.9 MiB so far)
# 26/04/30 13:26:47 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 1043.8 KiB so far)
# 26/04/30 13:26:47 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_556_0 in memory.
# 26/04/30 13:26:47 WARN MemoryStore: Not enough space to cache rdd_556_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:26:47 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_578_0 in memory.
# 26/04/30 13:26:47 WARN MemoryStore: Not enough space to cache rdd_578_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:26:47 WARN BlockManager: Persisting block rdd_578_0 to disk instead.
# 26/04/30 13:26:48 WARN MemoryStore: Not enough space to cache rdd_578_0 in memory! (computed 1035.5 KiB so far)
# 26/04/30 13:26:48 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_581_0 in memory.
# 26/04/30 13:26:48 WARN MemoryStore: Not enough space to cache rdd_581_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:26:48 WARN BlockManager: Persisting block rdd_581_0 to disk instead.
# 26/04/30 13:26:52 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:26:54 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:26:56 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:26:59 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:27:01 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:27:01 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 9.9 MiB so far)
# 26/04/30 13:27:01 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 1043.8 KiB so far)
# 26/04/30 13:27:01 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_578_0 in memory.
# 26/04/30 13:27:01 WARN MemoryStore: Not enough space to cache rdd_578_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:27:01 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_600_0 in memory.
# 26/04/30 13:27:01 WARN MemoryStore: Not enough space to cache rdd_600_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:27:01 WARN BlockManager: Persisting block rdd_600_0 to disk instead.
# 26/04/30 13:27:01 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block broadcast_604 in memory.
# 26/04/30 13:27:01 WARN MemoryStore: Not enough space to cache broadcast_604 in memory! (computed 504.0 B so far)
# 26/04/30 13:27:02 WARN MemoryStore: Not enough space to cache rdd_600_0 in memory! (computed 1035.5 KiB so far)
# 26/04/30 13:27:02 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_603_0 in memory.
# 26/04/30 13:27:02 WARN MemoryStore: Not enough space to cache rdd_603_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:27:02 WARN BlockManager: Persisting block rdd_603_0 to disk instead.
# 26/04/30 13:27:06 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:27:09 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:27:11 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:27:13 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:27:16 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:27:16 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 9.9 MiB so far)
# 26/04/30 13:27:16 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 1043.8 KiB so far)
# 26/04/30 13:27:16 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_600_0 in memory.
# 26/04/30 13:27:16 WARN MemoryStore: Not enough space to cache rdd_600_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:27:16 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_622_0 in memory.
# 26/04/30 13:27:16 WARN MemoryStore: Not enough space to cache rdd_622_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:27:16 WARN BlockManager: Persisting block rdd_622_0 to disk instead.
# 26/04/30 13:27:17 WARN MemoryStore: Not enough space to cache rdd_622_0 in memory! (computed 1035.5 KiB so far)
# 26/04/30 13:27:17 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_625_0 in memory.
# 26/04/30 13:27:17 WARN MemoryStore: Not enough space to cache rdd_625_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:27:17 WARN BlockManager: Persisting block rdd_625_0 to disk instead.
# 26/04/30 13:27:21 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:27:23 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:27:25 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:27:28 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:27:30 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:27:30 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 9.9 MiB so far)
# 26/04/30 13:27:30 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 1043.8 KiB so far)
# 26/04/30 13:27:30 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_622_0 in memory.
# 26/04/30 13:27:30 WARN MemoryStore: Not enough space to cache rdd_622_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:27:30 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_644_0 in memory.
# 26/04/30 13:27:30 WARN MemoryStore: Not enough space to cache rdd_644_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:27:30 WARN BlockManager: Persisting block rdd_644_0 to disk instead.
# 26/04/30 13:27:31 WARN MemoryStore: Not enough space to cache rdd_644_0 in memory! (computed 1035.5 KiB so far)
# 26/04/30 13:27:31 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_647_0 in memory.
# 26/04/30 13:27:31 WARN MemoryStore: Not enough space to cache rdd_647_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:27:31 WARN BlockManager: Persisting block rdd_647_0 to disk instead.
# 26/04/30 13:27:35 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:27:37 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:27:39 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:27:42 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:27:44 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:27:44 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 9.9 MiB so far)
# 26/04/30 13:27:44 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 1043.8 KiB so far)
# 26/04/30 13:27:44 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_644_0 in memory.
# 26/04/30 13:27:44 WARN MemoryStore: Not enough space to cache rdd_644_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:27:44 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_666_0 in memory.
# 26/04/30 13:27:44 WARN MemoryStore: Not enough space to cache rdd_666_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:27:44 WARN BlockManager: Persisting block rdd_666_0 to disk instead.
# 26/04/30 13:27:45 WARN MemoryStore: Not enough space to cache rdd_666_0 in memory! (computed 1035.5 KiB so far)
# 26/04/30 13:27:45 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_669_0 in memory.
# 26/04/30 13:27:45 WARN MemoryStore: Not enough space to cache rdd_669_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:27:45 WARN BlockManager: Persisting block rdd_669_0 to disk instead.
# 26/04/30 13:27:49 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:27:51 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:27:53 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:27:55 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:27:58 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:27:58 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 9.9 MiB so far)
# 26/04/30 13:27:58 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 1043.8 KiB so far)
# 26/04/30 13:27:58 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_666_0 in memory.
# 26/04/30 13:27:58 WARN MemoryStore: Not enough space to cache rdd_666_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:27:58 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_688_0 in memory.
# 26/04/30 13:27:58 WARN MemoryStore: Not enough space to cache rdd_688_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:27:58 WARN BlockManager: Persisting block rdd_688_0 to disk instead.
# 26/04/30 13:27:59 WARN MemoryStore: Not enough space to cache rdd_688_0 in memory! (computed 1035.5 KiB so far)
# 26/04/30 13:27:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_691_0 in memory.
# 26/04/30 13:27:59 WARN MemoryStore: Not enough space to cache rdd_691_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:27:59 WARN BlockManager: Persisting block rdd_691_0 to disk instead.
# 26/04/30 13:28:02 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:28:05 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:28:07 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:28:09 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:28:12 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:28:12 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 9.9 MiB so far)
# 26/04/30 13:28:12 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 1043.8 KiB so far)
# 26/04/30 13:28:12 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_688_0 in memory.
# 26/04/30 13:28:12 WARN MemoryStore: Not enough space to cache rdd_688_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:28:12 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_710_0 in memory.
# 26/04/30 13:28:12 WARN MemoryStore: Not enough space to cache rdd_710_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:28:12 WARN BlockManager: Persisting block rdd_710_0 to disk instead.
# 26/04/30 13:28:13 WARN MemoryStore: Not enough space to cache rdd_710_0 in memory! (computed 1035.5 KiB so far)
# 26/04/30 13:28:13 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_713_0 in memory.
# 26/04/30 13:28:13 WARN MemoryStore: Not enough space to cache rdd_713_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:28:13 WARN BlockManager: Persisting block rdd_713_0 to disk instead.
# 26/04/30 13:28:16 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:28:18 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:28:21 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:28:23 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:28:26 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:28:26 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 9.9 MiB so far)
# 26/04/30 13:28:26 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 1043.8 KiB so far)
# 26/04/30 13:28:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_710_0 in memory.
# 26/04/30 13:28:26 WARN MemoryStore: Not enough space to cache rdd_710_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:28:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_732_0 in memory.
# 26/04/30 13:28:26 WARN MemoryStore: Not enough space to cache rdd_732_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:28:26 WARN BlockManager: Persisting block rdd_732_0 to disk instead.
# 26/04/30 13:28:27 WARN MemoryStore: Not enough space to cache rdd_732_0 in memory! (computed 1035.5 KiB so far)
# 26/04/30 13:28:27 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_735_0 in memory.
# 26/04/30 13:28:27 WARN MemoryStore: Not enough space to cache rdd_735_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:28:27 WARN BlockManager: Persisting block rdd_735_0 to disk instead.
# 26/04/30 13:28:30 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:28:33 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:28:35 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:28:37 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:28:39 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:28:39 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 9.9 MiB so far)
# 26/04/30 13:28:39 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 1043.8 KiB so far)
# 26/04/30 13:28:39 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_732_0 in memory.
# 26/04/30 13:28:39 WARN MemoryStore: Not enough space to cache rdd_732_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:28:39 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_754_0 in memory.
# 26/04/30 13:28:39 WARN MemoryStore: Not enough space to cache rdd_754_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:28:39 WARN BlockManager: Persisting block rdd_754_0 to disk instead.
# 26/04/30 13:28:41 WARN MemoryStore: Not enough space to cache rdd_754_0 in memory! (computed 1035.5 KiB so far)
# 26/04/30 13:28:41 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_757_0 in memory.
# 26/04/30 13:28:41 WARN MemoryStore: Not enough space to cache rdd_757_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:28:41 WARN BlockManager: Persisting block rdd_757_0 to disk instead.
# 26/04/30 13:28:44 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:28:46 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:28:49 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:28:51 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:28:53 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:28:53 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 9.9 MiB so far)
# 26/04/30 13:28:53 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 1043.8 KiB so far)
# 26/04/30 13:28:53 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_754_0 in memory.
# 26/04/30 13:28:53 WARN MemoryStore: Not enough space to cache rdd_754_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:28:53 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_776_0 in memory.
# 26/04/30 13:28:53 WARN MemoryStore: Not enough space to cache rdd_776_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:28:53 WARN BlockManager: Persisting block rdd_776_0 to disk instead.
# 26/04/30 13:28:53 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block broadcast_604 in memory.
# 26/04/30 13:28:53 WARN MemoryStore: Not enough space to cache broadcast_604 in memory! (computed 504.0 B so far)
# 26/04/30 13:28:54 WARN MemoryStore: Not enough space to cache rdd_776_0 in memory! (computed 1035.5 KiB so far)
# 26/04/30 13:28:54 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_779_0 in memory.
# 26/04/30 13:28:54 WARN MemoryStore: Not enough space to cache rdd_779_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:28:54 WARN BlockManager: Persisting block rdd_779_0 to disk instead.
# 26/04/30 13:28:58 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:29:00 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:29:02 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:29:05 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:29:07 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:29:07 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 9.9 MiB so far)
# 26/04/30 13:29:07 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 1043.8 KiB so far)
# 26/04/30 13:29:07 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_776_0 in memory.
# 26/04/30 13:29:07 WARN MemoryStore: Not enough space to cache rdd_776_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:29:07 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_798_0 in memory.
# 26/04/30 13:29:07 WARN MemoryStore: Not enough space to cache rdd_798_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:29:07 WARN BlockManager: Persisting block rdd_798_0 to disk instead.
# 26/04/30 13:29:08 WARN MemoryStore: Not enough space to cache rdd_798_0 in memory! (computed 1035.5 KiB so far)
# 26/04/30 13:29:08 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_801_0 in memory.
# 26/04/30 13:29:08 WARN MemoryStore: Not enough space to cache rdd_801_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:29:08 WARN BlockManager: Persisting block rdd_801_0 to disk instead.
# 26/04/30 13:29:12 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:29:14 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:29:16 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:29:19 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:29:21 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:29:21 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 9.9 MiB so far)
# 26/04/30 13:29:21 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 1043.8 KiB so far)
# 26/04/30 13:29:21 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_798_0 in memory.
# 26/04/30 13:29:21 WARN MemoryStore: Not enough space to cache rdd_798_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:29:21 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_820_0 in memory.
# 26/04/30 13:29:21 WARN MemoryStore: Not enough space to cache rdd_820_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:29:21 WARN BlockManager: Persisting block rdd_820_0 to disk instead.
# 26/04/30 13:29:22 WARN MemoryStore: Not enough space to cache rdd_820_0 in memory! (computed 1035.5 KiB so far)
# 26/04/30 13:29:22 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_823_0 in memory.
# 26/04/30 13:29:22 WARN MemoryStore: Not enough space to cache rdd_823_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:29:22 WARN BlockManager: Persisting block rdd_823_0 to disk instead.
# 26/04/30 13:29:26 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:29:28 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:29:30 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:29:35 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:29:38 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:29:38 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 9.9 MiB so far)
# 26/04/30 13:29:38 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 1043.8 KiB so far)
# 26/04/30 13:29:38 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_820_0 in memory.
# 26/04/30 13:29:38 WARN MemoryStore: Not enough space to cache rdd_820_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:29:38 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_842_0 in memory.
# 26/04/30 13:29:38 WARN MemoryStore: Not enough space to cache rdd_842_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:29:38 WARN BlockManager: Persisting block rdd_842_0 to disk instead.
# 26/04/30 13:29:39 WARN MemoryStore: Not enough space to cache rdd_842_0 in memory! (computed 1035.5 KiB so far)
# 26/04/30 13:29:39 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_845_0 in memory.
# 26/04/30 13:29:39 WARN MemoryStore: Not enough space to cache rdd_845_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:29:39 WARN BlockManager: Persisting block rdd_845_0 to disk instead.
# 26/04/30 13:29:43 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:29:45 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:29:47 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:29:50 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:29:52 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:29:52 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 9.9 MiB so far)
# 26/04/30 13:29:52 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 1043.8 KiB so far)
# 26/04/30 13:29:52 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_842_0 in memory.
# 26/04/30 13:29:52 WARN MemoryStore: Not enough space to cache rdd_842_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:29:52 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_864_0 in memory.
# 26/04/30 13:29:52 WARN MemoryStore: Not enough space to cache rdd_864_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:29:52 WARN BlockManager: Persisting block rdd_864_0 to disk instead.
# 26/04/30 13:29:53 WARN MemoryStore: Not enough space to cache rdd_864_0 in memory! (computed 1035.5 KiB so far)
# 26/04/30 13:29:53 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_867_0 in memory.
# 26/04/30 13:29:53 WARN MemoryStore: Not enough space to cache rdd_867_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:29:53 WARN BlockManager: Persisting block rdd_867_0 to disk instead.
# 26/04/30 13:29:57 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:29:59 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:30:02 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:30:04 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:30:06 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:30:06 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 9.9 MiB so far)
# 26/04/30 13:30:06 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 1043.8 KiB so far)
# 26/04/30 13:30:06 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_864_0 in memory.
# 26/04/30 13:30:06 WARN MemoryStore: Not enough space to cache rdd_864_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:30:06 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_886_0 in memory.
# 26/04/30 13:30:06 WARN MemoryStore: Not enough space to cache rdd_886_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:30:06 WARN BlockManager: Persisting block rdd_886_0 to disk instead.
# 26/04/30 13:30:08 WARN MemoryStore: Not enough space to cache rdd_886_0 in memory! (computed 1035.5 KiB so far)
# 26/04/30 13:30:08 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_889_0 in memory.
# 26/04/30 13:30:08 WARN MemoryStore: Not enough space to cache rdd_889_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:30:08 WARN BlockManager: Persisting block rdd_889_0 to disk instead.
# 26/04/30 13:30:11 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:30:13 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:30:16 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:30:18 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:30:20 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:30:20 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 9.9 MiB so far)
# 26/04/30 13:30:20 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 1043.8 KiB so far)
# 26/04/30 13:30:20 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_886_0 in memory.
# 26/04/30 13:30:20 WARN MemoryStore: Not enough space to cache rdd_886_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:30:20 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_908_0 in memory.
# 26/04/30 13:30:20 WARN MemoryStore: Not enough space to cache rdd_908_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:30:20 WARN BlockManager: Persisting block rdd_908_0 to disk instead.
# 26/04/30 13:30:22 WARN MemoryStore: Not enough space to cache rdd_908_0 in memory! (computed 1035.5 KiB so far)
# 26/04/30 13:30:22 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_911_0 in memory.
# 26/04/30 13:30:22 WARN MemoryStore: Not enough space to cache rdd_911_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:30:22 WARN BlockManager: Persisting block rdd_911_0 to disk instead.
# 26/04/30 13:30:25 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:30:27 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:30:30 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:30:32 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:30:34 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:30:34 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 9.9 MiB so far)
# 26/04/30 13:30:34 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 1043.8 KiB so far)
# 26/04/30 13:30:34 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_908_0 in memory.
# 26/04/30 13:30:34 WARN MemoryStore: Not enough space to cache rdd_908_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:30:34 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_930_0 in memory.
# 26/04/30 13:30:34 WARN MemoryStore: Not enough space to cache rdd_930_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:30:34 WARN BlockManager: Persisting block rdd_930_0 to disk instead.
# 26/04/30 13:30:36 WARN MemoryStore: Not enough space to cache rdd_930_0 in memory! (computed 1035.5 KiB so far)
# 26/04/30 13:30:36 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_933_0 in memory.
# 26/04/30 13:30:36 WARN MemoryStore: Not enough space to cache rdd_933_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:30:36 WARN BlockManager: Persisting block rdd_933_0 to disk instead.
# 26/04/30 13:30:39 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:30:41 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:30:44 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:30:46 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:30:48 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:30:48 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 9.9 MiB so far)
# 26/04/30 13:30:48 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 1043.8 KiB so far)
# 26/04/30 13:30:48 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_930_0 in memory.
# 26/04/30 13:30:48 WARN MemoryStore: Not enough space to cache rdd_930_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:30:48 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_952_0 in memory.
# 26/04/30 13:30:48 WARN MemoryStore: Not enough space to cache rdd_952_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:30:48 WARN BlockManager: Persisting block rdd_952_0 to disk instead.
# 26/04/30 13:30:50 WARN MemoryStore: Not enough space to cache rdd_952_0 in memory! (computed 1035.5 KiB so far)
# 26/04/30 13:30:50 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_955_0 in memory.
# 26/04/30 13:30:50 WARN MemoryStore: Not enough space to cache rdd_955_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:30:50 WARN BlockManager: Persisting block rdd_955_0 to disk instead.
# 26/04/30 13:30:53 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:30:55 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:30:58 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:31:00 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:31:02 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:31:02 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 9.9 MiB so far)
# 26/04/30 13:31:02 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 1043.8 KiB so far)
# 26/04/30 13:31:02 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_952_0 in memory.
# 26/04/30 13:31:02 WARN MemoryStore: Not enough space to cache rdd_952_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:31:02 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_974_0 in memory.
# 26/04/30 13:31:02 WARN MemoryStore: Not enough space to cache rdd_974_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:31:02 WARN BlockManager: Persisting block rdd_974_0 to disk instead.
# 26/04/30 13:31:03 WARN MemoryStore: Not enough space to cache rdd_974_0 in memory! (computed 1035.5 KiB so far)
# 26/04/30 13:31:03 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_977_0 in memory.
# 26/04/30 13:31:03 WARN MemoryStore: Not enough space to cache rdd_977_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:31:03 WARN BlockManager: Persisting block rdd_977_0 to disk instead.
# 26/04/30 13:31:07 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:31:09 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:31:12 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:31:14 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:31:16 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:31:16 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 9.9 MiB so far)
# 26/04/30 13:31:16 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 1043.8 KiB so far)
# 26/04/30 13:31:16 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_974_0 in memory.
# 26/04/30 13:31:16 WARN MemoryStore: Not enough space to cache rdd_974_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:31:16 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_996_0 in memory.
# 26/04/30 13:31:16 WARN MemoryStore: Not enough space to cache rdd_996_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:31:16 WARN BlockManager: Persisting block rdd_996_0 to disk instead.
# 26/04/30 13:31:17 WARN MemoryStore: Not enough space to cache rdd_996_0 in memory! (computed 1035.5 KiB so far)
# 26/04/30 13:31:17 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_999_0 in memory.
# 26/04/30 13:31:17 WARN MemoryStore: Not enough space to cache rdd_999_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:31:17 WARN BlockManager: Persisting block rdd_999_0 to disk instead.
# 26/04/30 13:31:21 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:31:23 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:31:25 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:31:28 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:31:30 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:31:30 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 9.9 MiB so far)
# 26/04/30 13:31:30 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 1043.8 KiB so far)
# 26/04/30 13:31:30 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_996_0 in memory.
# 26/04/30 13:31:30 WARN MemoryStore: Not enough space to cache rdd_996_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:31:30 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_1018_0 in memory.
# 26/04/30 13:31:30 WARN MemoryStore: Not enough space to cache rdd_1018_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:31:30 WARN BlockManager: Persisting block rdd_1018_0 to disk instead.
# 26/04/30 13:31:31 WARN MemoryStore: Not enough space to cache rdd_1018_0 in memory! (computed 1035.5 KiB so far)
# 26/04/30 13:31:31 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_1021_0 in memory.
# 26/04/30 13:31:31 WARN MemoryStore: Not enough space to cache rdd_1021_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:31:31 WARN BlockManager: Persisting block rdd_1021_0 to disk instead.
# 26/04/30 13:31:35 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:31:37 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:31:40 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:31:42 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:31:44 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:31:44 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 9.9 MiB so far)
# 26/04/30 13:31:44 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 1043.8 KiB so far)
# 26/04/30 13:31:44 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_1018_0 in memory.
# 26/04/30 13:31:44 WARN MemoryStore: Not enough space to cache rdd_1018_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:31:44 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_1040_0 in memory.
# 26/04/30 13:31:44 WARN MemoryStore: Not enough space to cache rdd_1040_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:31:44 WARN BlockManager: Persisting block rdd_1040_0 to disk instead.
# 26/04/30 13:31:45 WARN MemoryStore: Not enough space to cache rdd_1040_0 in memory! (computed 1035.5 KiB so far)
# 26/04/30 13:31:45 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_1043_0 in memory.
# 26/04/30 13:31:45 WARN MemoryStore: Not enough space to cache rdd_1043_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:31:45 WARN BlockManager: Persisting block rdd_1043_0 to disk instead.
# 26/04/30 13:31:49 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:31:51 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:31:53 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:31:56 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:31:58 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:31:58 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 9.9 MiB so far)
# 26/04/30 13:31:58 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 1043.8 KiB so far)
# 26/04/30 13:31:58 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_1040_0 in memory.
# 26/04/30 13:31:58 WARN MemoryStore: Not enough space to cache rdd_1040_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:31:58 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_1062_0 in memory.
# 26/04/30 13:31:58 WARN MemoryStore: Not enough space to cache rdd_1062_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:31:58 WARN BlockManager: Persisting block rdd_1062_0 to disk instead.
# 26/04/30 13:31:59 WARN MemoryStore: Not enough space to cache rdd_1062_0 in memory! (computed 1035.5 KiB so far)
# 26/04/30 13:31:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_1065_0 in memory.
# 26/04/30 13:31:59 WARN MemoryStore: Not enough space to cache rdd_1065_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:31:59 WARN BlockManager: Persisting block rdd_1065_0 to disk instead.
# 26/04/30 13:32:03 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:32:05 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:32:07 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:32:10 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:32:12 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:32:12 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 9.9 MiB so far)
# 26/04/30 13:32:12 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 1043.8 KiB so far)
# 26/04/30 13:32:12 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_1062_0 in memory.
# 26/04/30 13:32:12 WARN MemoryStore: Not enough space to cache rdd_1062_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:32:12 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_1084_0 in memory.
# 26/04/30 13:32:12 WARN MemoryStore: Not enough space to cache rdd_1084_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:32:12 WARN BlockManager: Persisting block rdd_1084_0 to disk instead.
# 26/04/30 13:32:13 WARN MemoryStore: Not enough space to cache rdd_1084_0 in memory! (computed 1035.5 KiB so far)
# 26/04/30 13:32:13 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_1087_0 in memory.
# 26/04/30 13:32:13 WARN MemoryStore: Not enough space to cache rdd_1087_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:32:13 WARN BlockManager: Persisting block rdd_1087_0 to disk instead.
# 26/04/30 13:32:17 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:32:19 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:32:21 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:32:23 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:32:26 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:32:26 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 9.9 MiB so far)
# 26/04/30 13:32:26 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 1043.8 KiB so far)
# 26/04/30 13:32:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_1084_0 in memory.
# 26/04/30 13:32:26 WARN MemoryStore: Not enough space to cache rdd_1084_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:32:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_1106_0 in memory.
# 26/04/30 13:32:26 WARN MemoryStore: Not enough space to cache rdd_1106_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:32:26 WARN BlockManager: Persisting block rdd_1106_0 to disk instead.
# 26/04/30 13:32:27 WARN MemoryStore: Not enough space to cache rdd_1106_0 in memory! (computed 1035.5 KiB so far)
# 26/04/30 13:32:27 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_1109_0 in memory.
# 26/04/30 13:32:27 WARN MemoryStore: Not enough space to cache rdd_1109_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:32:27 WARN BlockManager: Persisting block rdd_1109_0 to disk instead.
# 26/04/30 13:32:31 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:32:33 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:32:35 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:32:37 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:32:40 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:32:40 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 9.9 MiB so far)
# 26/04/30 13:32:40 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 1043.8 KiB so far)
# 26/04/30 13:32:40 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_1106_0 in memory.
# ...
# 26/04/30 13:37:17 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_1461_0 in memory.
# 26/04/30 13:37:17 WARN MemoryStore: Not enough space to cache rdd_1461_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:37:17 WARN BlockManager: Persisting block rdd_1461_0 to disk instead.
# 26/04/30 13:37:21 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:41:19 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:41:22 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:41:24 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:41:26 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:41:26 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 9.9 MiB so far)
# 26/04/30 13:41:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_536_0 in memory.
# 26/04/30 13:41:26 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:41:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_1458_0 in memory.
# 26/04/30 13:41:26 WARN MemoryStore: Not enough space to cache rdd_1458_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:41:26 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_1480_0 in memory.
# 26/04/30 13:41:26 WARN MemoryStore: Not enough space to cache rdd_1480_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:41:26 WARN BlockManager: Persisting block rdd_1480_0 to disk instead.
# 26/04/30 13:41:28 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_1480_0 in memory.
# 26/04/30 13:41:28 WARN MemoryStore: Not enough space to cache rdd_1480_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:41:28 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_1483_0 in memory.
# 26/04/30 13:41:28 WARN MemoryStore: Not enough space to cache rdd_1483_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:41:28 WARN BlockManager: Persisting block rdd_1483_0 to disk instead.
# 26/04/30 13:41:31 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:41:33 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:41:36 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:41:38 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:42:20 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:42:20 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 9.9 MiB so far)
# 26/04/30 13:42:20 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_536_0 in memory.
# 26/04/30 13:42:20 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:42:20 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_1480_0 in memory.
# 26/04/30 13:42:20 WARN MemoryStore: Not enough space to cache rdd_1480_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:42:20 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_1502_0 in memory.
# 26/04/30 13:42:20 WARN MemoryStore: Not enough space to cache rdd_1502_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:42:20 WARN BlockManager: Persisting block rdd_1502_0 to disk instead.
# 26/04/30 13:42:21 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_1502_0 in memory.
# 26/04/30 13:42:21 WARN MemoryStore: Not enough space to cache rdd_1502_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:42:21 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_1505_0 in memory.
# 26/04/30 13:42:21 WARN MemoryStore: Not enough space to cache rdd_1505_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:42:21 WARN BlockManager: Persisting block rdd_1505_0 to disk instead.
# 26/04/30 13:42:25 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:42:27 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:42:29 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:42:31 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:42:34 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:42:34 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 9.9 MiB so far)
# 26/04/30 13:42:34 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_536_0 in memory.
# 26/04/30 13:42:34 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:42:34 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_1502_0 in memory.
# 26/04/30 13:42:34 WARN MemoryStore: Not enough space to cache rdd_1502_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:42:34 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_1524_0 in memory.
# 26/04/30 13:42:34 WARN MemoryStore: Not enough space to cache rdd_1524_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:42:34 WARN BlockManager: Persisting block rdd_1524_0 to disk instead.
# 26/04/30 13:44:03 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_1524_0 in memory.
# 26/04/30 13:44:03 WARN MemoryStore: Not enough space to cache rdd_1524_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:44:03 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_1527_0 in memory.
# 26/04/30 13:44:03 WARN MemoryStore: Not enough space to cache rdd_1527_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:44:03 WARN BlockManager: Persisting block rdd_1527_0 to disk instead.
# 26/04/30 13:44:07 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:45:23 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:45:28 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:45:52 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:45:57 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:45:57 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 9.9 MiB so far)
# 26/04/30 13:45:57 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_536_0 in memory.
# 26/04/30 13:45:57 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:45:57 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_1524_0 in memory.
# 26/04/30 13:45:57 WARN MemoryStore: Not enough space to cache rdd_1524_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:45:57 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_1546_0 in memory.
# 26/04/30 13:45:57 WARN MemoryStore: Not enough space to cache rdd_1546_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:45:57 WARN BlockManager: Persisting block rdd_1546_0 to disk instead.
# 26/04/30 13:45:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_1546_0 in memory.
# 26/04/30 13:45:59 WARN MemoryStore: Not enough space to cache rdd_1546_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:45:59 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_1549_0 in memory.
# 26/04/30 13:45:59 WARN MemoryStore: Not enough space to cache rdd_1549_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:45:59 WARN BlockManager: Persisting block rdd_1549_0 to disk instead.
# 26/04/30 13:46:02 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:46:05 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:46:17 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:46:22 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:46:28 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:46:28 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 9.9 MiB so far)
# 26/04/30 13:46:28 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_536_0 in memory.
# 26/04/30 13:46:28 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:46:28 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_1546_0 in memory.
# 26/04/30 13:46:28 WARN MemoryStore: Not enough space to cache rdd_1546_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:46:28 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_1568_0 in memory.
# 26/04/30 13:46:28 WARN MemoryStore: Not enough space to cache rdd_1568_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:46:28 WARN BlockManager: Persisting block rdd_1568_0 to disk instead.
# 26/04/30 13:46:30 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_1568_0 in memory.
# 26/04/30 13:46:30 WARN MemoryStore: Not enough space to cache rdd_1568_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:46:30 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_1571_0 in memory.
# 26/04/30 13:46:30 WARN MemoryStore: Not enough space to cache rdd_1571_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:46:30 WARN BlockManager: Persisting block rdd_1571_0 to disk instead.
# 26/04/30 13:46:34 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:46:36 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:46:38 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:46:41 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:46:43 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:46:43 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 9.9 MiB so far)
# 26/04/30 13:46:43 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_536_0 in memory.
# 26/04/30 13:46:43 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:46:43 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_1568_0 in memory.
# 26/04/30 13:46:43 WARN MemoryStore: Not enough space to cache rdd_1568_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:46:43 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_1590_0 in memory.
# 26/04/30 13:46:43 WARN MemoryStore: Not enough space to cache rdd_1590_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:46:43 WARN BlockManager: Persisting block rdd_1590_0 to disk instead.
# 26/04/30 13:46:44 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_1590_0 in memory.
# 26/04/30 13:46:44 WARN MemoryStore: Not enough space to cache rdd_1590_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:46:44 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_1593_0 in memory.
# 26/04/30 13:46:44 WARN MemoryStore: Not enough space to cache rdd_1593_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:46:44 WARN BlockManager: Persisting block rdd_1593_0 to disk instead.
# 26/04/30 13:46:48 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:46:50 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:46:52 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:48:13 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:48:16 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:48:16 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 9.9 MiB so far)
# 26/04/30 13:48:16 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_536_0 in memory.
# 26/04/30 13:48:16 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:48:16 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_1590_0 in memory.
# 26/04/30 13:48:16 WARN MemoryStore: Not enough space to cache rdd_1590_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:48:16 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_1612_0 in memory.
# 26/04/30 13:48:16 WARN MemoryStore: Not enough space to cache rdd_1612_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:48:16 WARN BlockManager: Persisting block rdd_1612_0 to disk instead.
# 26/04/30 13:48:19 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_1612_0 in memory.
# 26/04/30 13:48:19 WARN MemoryStore: Not enough space to cache rdd_1612_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:48:19 WARN MemoryStore: Failed to reserve initial memory threshold of 1024.0 KiB for computing block rdd_1615_0 in memory.
# 26/04/30 13:48:19 WARN MemoryStore: Not enough space to cache rdd_1615_0 in memory! (computed 504.0 B so far)
# 26/04/30 13:48:19 WARN BlockManager: Persisting block rdd_1615_0 to disk instead.
# 26/04/30 13:48:26 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:48:29 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:48:31 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# 26/04/30 13:48:33 WARN MemoryStore: Not enough space to cache rdd_536_0 in memory! (computed 423.3 MiB so far)
# [Stage 824:>                                                        (0 + 8) / 8]
# +------------------+------------------+-------------------+------------------+------------------+
# |accuracy          |f1                |model              |precision         |recall            |
# +------------------+------------------+-------------------+------------------+------------------+
# |0.9257538432754373|0.9180563016456859|Logistic Regression|0.917199218390758 |0.9257538432754373|
# |0.9197979357011444|0.899928933818223 |GBT Classifier     |0.9142400205266696|0.9197979357011444|
# |0.9130312763104556|0.8857872285396695|Linear SVM         |0.9086311792876524|0.9130312763104556|
# |0.9090710655149833|0.9092192740518286|Naive Bayes        |0.9093692955133021|0.9090710655149833|
# +------------------+------------------+-------------------+------------------+------------------+

# %% [markdown]
# ## 7. Confusion Matrices for At Least Two Models
#
# The project requires a confusion matrix for at least two models.

# %%
def show_confusion_matrix(preds, title):
    print(f"\nConfusion Matrix: {title}")
    (
        preds.groupBy("label", "prediction")
        .count()
        .orderBy("label", "prediction")
        .show()
    )

# Show confusion matrices for two example models.
show_confusion_matrix(predictions_dict["Logistic Regression"], "Logistic Regression")
show_confusion_matrix(predictions_dict["Naive Bayes"], "Naive Bayes")
# Out:
# Confusion Matrix: Logistic Regression
# +-----+----------+-----+
# |label|prediction|count|
# +-----+----------+-----+
# |  0.0|       0.0|28230|
# |  0.0|       1.0|  587|
# |  1.0|       0.0| 1794|
# |  1.0|       1.0| 1458|
# +-----+----------+-----+
#
#
# Confusion Matrix: Naive Bayes
# [Stage 828:>                                                        (0 + 1) / 1]
# +-----+----------+-----+
# |label|prediction|count|
# +-----+----------+-----+
# |  0.0|       0.0|27347|
# |  0.0|       1.0| 1470|
# |  1.0|       0.0| 1446|
# |  1.0|       1.0| 1806|
# +-----+----------+-----+

# %%
import matplotlib.pyplot as plt
import numpy as np

# Function to plot confusion matrix from Spark DataFrame predictions.
def plot_confusion_matrix(preds_df, model_name):
    # Convert confusion matrix data to pandas for plotting.
    cm_pdf = (
        preds_df.groupBy("label", "prediction")
        .count()
        .orderBy("label", "prediction")
        .toPandas()
    )
    # Create a 2x2 confusion matrix array.
    cm_array = np.zeros((2, 2), dtype=int)
    for _, row in cm_pdf.iterrows():
        i = int(row["label"])
        j = int(row["prediction"])
        cm_array[i][j] = int(row["count"])
    
    # Plotting the confusion matrix.
    class_names = ["non-toxic", "toxic"]
    fig, ax = plt.subplots(figsize=(6, 5))
    im = ax.imshow(cm_array, interpolation="nearest", cmap="Blues")
    plt.colorbar(im, ax=ax)
    ax.set_xticks(range(2)); ax.set_xticklabels(class_names, rotation=30, ha="right")
    ax.set_yticks(range(2)); ax.set_yticklabels(class_names)
    ax.set_xlabel("Predicted Label")
    ax.set_ylabel("True Label")
    ax.set_title(f"Confusion Matrix - {model_name}")
    
    # Add text annotations.
    thresh = cm_array.max() / 2
    for i in range(2):
        for j in range(2):
            ax.text(j, i, str(cm_array[i, j]), ha="center", va="center",
                    color="white" if cm_array[i, j] > thresh else "black", fontsize=13)
    plt.tight_layout()
    plt.show()

# Plot confusion matrices for two example models.
plot_confusion_matrix(predictions_dict["Logistic Regression"], "Logistic Regression")
plot_confusion_matrix(predictions_dict["Naive Bayes"], "Naive Bayes")

# %% [markdown]
# ## 8. Convert Results to a Local Table for Plotting
#
# Small result tables can be converted locally for plotting.
# This does **not** violate the Spark requirement because the ML workflow itself remains in Spark.

# %%
import pandas as pd
import matplotlib.pyplot as plt
# Convert Spark DataFrame to Pandas for plotting
plot_df = results_df.toPandas()
plot_df
# Out:
#    accuracy        f1                model  precision    recall
# 0  0.925754  0.918056  Logistic Regression   0.917199  0.925754
# 1  0.919798  0.899929       GBT Classifier   0.914240  0.919798
# 2  0.913031  0.885787           Linear SVM   0.908631  0.913031
# 3  0.909071  0.909219          Naive Bayes   0.909369  0.909071

# %%
# Simple comparison chart.
plt.figure(figsize=(10, 5))
plt.bar(plot_df["model"], plot_df["accuracy"])
plt.xticks(rotation=45, ha="right")
plt.ylabel("Accuracy")
plt.title("Model Accuracy Comparison on Jigsaw Toxic Comment Test Set")
plt.tight_layout()
plt.show()

# %%
# Grouped bar chart comparing all 4 metrics across all models.
import numpy as np

# Define metrics and colors for the plot.
metrics = ["accuracy", "f1", "precision", "recall"]
model_names = plot_df["model"].tolist()
x = np.arange(len(model_names))
width = 0.2
colors = ["#4C72B0", "#DD8452", "#55A868", "#C44E52"]

fig, ax = plt.subplots(figsize=(14, 6))
# Create bars for each metric.
for i, (metric, color) in enumerate(zip(metrics, colors)):
    ax.bar(x + i * width, plot_df[metric], width, label=metric, color=color, alpha=0.85)
# Set x-ticks and labels.
ax.set_xticks(x + width * 1.5)
ax.set_xticklabels(model_names, rotation=25, ha="right", fontsize=9)
ax.set_ylim(0.0, 1.05)
ax.set_ylabel("Score")
ax.set_title("Model Comparison - All Metrics on Jigsaw Toxic Comment Test Set")
ax.legend(loc="lower right")
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 9. Interpretation Notes for Students
#
# In your notebook and report, explain:
# - Which model performed best?
# - Whether the results were close or very different
# - Why some models may perform better or worse on sparse text features
# - How class imbalance affects accuracy, precision, recall, and F1
# - Any limitations of converting the original six-label Kaggle task into one binary `any toxic` label
#
# You should not only show numbers; you should also interpret them.

# %% [markdown]
# ## 10. Required Report Reminder
#
# Your report should summarize:
# 1. The workflow you used
# 2. The Spark pipeline components
# 3. The models you trained
# 4. The evaluation results
# 5. Your discussion and conclusions

# %% [markdown]
# ## 11. Important Reminder About Phase 2
#
# This notebook now uses the Jigsaw toxic comment dataset and can be extended further by training one model per toxicity label or by using Spark NLP-style feature engineering.

# %% [markdown]
# ## 12. Checklist Before Submission
#
# - [ ] Used Spark DataFrames
# - [ ] Used Spark ML Pipeline components
# - [ ] Trained at least 6 approved models
# - [ ] Reported accuracy, precision, recall, and F1
# - [ ] Included confusion matrices for at least 2 models
# - [ ] Compared models in a table or figure
# - [ ] Wrote clear comments in the notebook
# - [ ] Prepared the 3–4 page report
